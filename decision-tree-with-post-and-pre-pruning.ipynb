# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
df = sns.load_dataset('iris')

# %%
X = df.iloc[:,:-1]
y = iris.target

# %%
X.head()

# %%
y

# %%
### Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()

# %%
classifier.fit(X_train, y_train)

# %%
# Plotting the tree

# %%
from sklearn import tree
plt.figure(figsize = (30,20))
tree.plot_tree(classifier, filled = True)

# %%
from sklearn.metrics import accuracy_score, classification_report
y_pred = classifier.predict(X_test)
print(accuracy_score(y_pred, y_test))
print(classification_report(y_pred, y_test))

# %%
# After the left side with 0,47,1 we don't require splitting 
# Same is with the right side for 0,1,45 
# Therefore we would tune the hyperparameters and reduce the tree

# %% [markdown]
# POST PRUNING OF DECISION TREE - In this, we first construct the tree and then we do hyperparameter tuning

# %%
classifier = DecisionTreeClassifier(max_depth = 2)
classifier.fit(X_train, y_train)
plt.figure(figsize = (30,20))
tree.plot_tree(classifier, filled = True)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
print(accuracy_score(y_pred, y_test))

# %%
print(classification_report(y_pred, y_test))

# %% [markdown]
# PRE PRUNING - The hyperparameters are tuned before making the tree.

# %%
parameter={
 'criterion':['gini','entropy','log_loss'],
  'splitter':['best','random'],
  'max_depth':[1,2,3,4,5],
  'max_features':['auto', 'sqrt', 'log2']
    
}

# %%
from sklearn.model_selection import GridSearchCV
treemodel=DecisionTreeClassifier()
cv=GridSearchCV(treemodel,param_grid=parameter,cv=5,scoring='accuracy')
cv.fit(X_train,y_train)

# %%
cv.best_params_

# %%
y_test

# %%
cv.predict(X_test)

# %%
print(accuracy_score(y_pred, y_test))
print(classification_report(y_pred, y_test))
